# %%
import pandas as pd
import json

# %%
df = pd.read_csv("/home/david/Escritorio/pythonProjects/Caca/trips_23_02_February-csv/trips_23_02_February.csv", sep=";")
df = df.dropna().reset_index().drop(columns=["index"])

# %%
unlock_lat = []
unlock_lon = []
for d in df["geolocation_unlock"]:
    d = json.loads(d.replace("'", "\""))
    unlock_lat.append(d["coordinates"][1])
    unlock_lon.append(d["coordinates"][0])

lock_lat = []
lock_lon = []
for d in df["geolocation_lock"]:
    d = json.loads(d.replace("'", "\""))
    lock_lat.append(d["coordinates"][1])
    lock_lon.append(d["coordinates"][0])

df = df.drop(columns=["geolocation_unlock", "geolocation_lock"])

df["unlock_latitude"] = unlock_lat
df["unlock_longitude"] = unlock_lon

df["lock_latitude"] = lock_lat
df["lock_longitude"] = lock_lon

# %%
df["unlock_date"] = df["unlock_date"].apply(lambda x: x.replace("T", " "))
df["lock_date"] = df["lock_date"].apply(lambda x: x.replace("T", " "))

# %%
df
# Out:
#              fecha  idBike  fleet  trip_minutes  \
# 0       2023-02-01  7337.0    1.0          5.52
# 1       2023-02-01  5098.0    1.0          0.32
# 2       2023-02-01  6519.0    1.0          0.27
# 3       2023-02-01  2551.0    1.0          8.58
# 4       2023-02-01  6519.0    1.0          0.20
# ...            ...     ...    ...           ...
# 167941  2023-02-18  7492.0    1.0          1.33
# 167942  2023-02-18  5538.0    1.0          9.48
# 167943  2023-02-18  6473.0    1.0          0.47
# 167944  2023-02-18  5252.0    1.0          7.43
# 167945  2023-02-18  3077.0    1.0          0.12
#
#                         address_unlock          unlock_date locktype  \
# 0                   'Calle Jesús nº 1'  2023-02-01 00:00:10  STATION
# 1       'Glorieta de Embajadores nº 2'  2023-02-01 00:00:25  STATION
# 2          'Calle Antonio Maura nº 15'  2023-02-01 00:00:36  STATION
# 3       'Glorieta de Embajadores nº 2'  2023-02-01 00:00:53  STATION
# 4          'Calle Antonio Maura nº 15'  2023-02-01 00:00:57  STATION
# ...                                ...                  ...      ...
# 167941        'Calle Jacometrezo nº 3'  2023-02-18 04:25:31  STATION
# 167942        'Calle Jacometrezo nº 3'  2023-02-18 04:27:30  STATION
# 167943  'Calle Doctor Esquerdo nº 191'  2023-02-18 04:39:38  STATION
# 167944             'Calle Sodio nº 1B'  2023-02-18 04:42:50  STATION
# 167945                 'Plaza Cibeles'  2023-02-18 07:22:48  STATION
#
#        unlocktype                      address_lock            lock_date  \
# 0         STATION       'Plaza de la Cebada nº 16 '  2023-02-01 00:05:41
# 1         STATION    'Glorieta de Embajadores nº 2'  2023-02-01 00:00:44
# 2         STATION       'Calle Antonio Maura nº 15'  2023-02-01 00:00:52
# 3         STATION              'Calle Atocha nº 54'  2023-02-01 00:09:28
# 4         STATION       'Calle Antonio Maura nº 15'  2023-02-01 00:01:09
# ...           ...                               ...                  ...
# 167941    STATION          'Calle Jacometrezo nº 3'  2023-02-18 04:26:51
# 167942    STATION  'Calle San Vicente Ferrer nº 64'  2023-02-18 04:36:59
# 167943    STATION    'Calle Doctor Esquerdo nº 191'  2023-02-18 04:40:06
# 167944    STATION      'Paseo de la Esperanza nº 2'  2023-02-18 04:50:16
# 167945    STATION                   'Plaza Cibeles'  2023-02-18 07:22:55
#
#         station_unlock  dock_unlock    unlock_station_name  station_lock  \
# 0                 31.0          3.0           27 - Huertas          43.0
# 1                 52.0         22.0     48 - Embajadores 2          52.0
# 2                 69.0          9.0     65 - Antonio Maura          69.0
# 3                 52.0         23.0     48 - Embajadores 2          45.0
# 4                 69.0          9.0     65 - Antonio Maura          69.0
# ...                ...          ...                    ...           ...
# 167941            25.0         15.0       22 - Jacometrezo          25.0
# 167942            25.0          5.0       22 - Jacometrezo          16.0
# 167943            89.0         23.0       84 - Valderribas          89.0
# 167944           243.0          1.0  235 - Embajadores 191         134.0
# 167945            91.0         14.0           86 - Cibeles          91.0
#
#         dock_lock            lock_station_name  unlock_latitude  \
# 0             3.0      39 - Plaza de la Cebada        40.413280
# 1            22.0           48 - Embajadores 2        40.405611
# 2             9.0           65 - Antonio Maura        40.416683
# 3             3.0            41 - Antón Martín        40.405611
# 4             9.0           65 - Antonio Maura        40.416683
# ...           ...                          ...              ...
# 167941       11.0             22 - Jacometrezo        40.420078
# 167942        9.0      15 - San Vicente Ferrer        40.420078
# 167943       23.0             84 - Valderribas        40.403250
# 167944       13.0  163 - Paseo de la Esperanza        40.389259
# 167945       14.0                 86 - Cibeles        40.418652
#
#         unlock_longitude  lock_latitude  lock_longitude
# 0              -3.695618      40.411274       -3.708834
# 1              -3.702259      40.405611       -3.702259
# 2              -3.689419      40.416683       -3.689419
# 3              -3.702259      40.412205       -3.699115
# 4              -3.689419      40.416683       -3.689419
# ...                  ...            ...             ...
# 167941         -3.706538      40.420078       -3.706538
# 167942         -3.706538      40.426238       -3.707445
# 167943         -3.672602      40.403250       -3.672602
# 167944         -3.690359      40.403599       -3.706452
# 167945         -3.693350      40.418652       -3.693350
#
# [167946 rows x 20 columns]
